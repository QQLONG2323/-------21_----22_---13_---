# %%
import numpy as np
na = np.genfromtxt('election.csv', delimiter=',', skip_header=1)
print(na.shape)
# Out:
# (15887, 10)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks")
election_data = pd.read_csv("election.csv")  
sns.displot(data=election_data,x="city",y="VMDPP", color="green")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks")
election_data = pd.read_csv("election.csv")  
sns.displot(data=election_data,x="city",y="VMKMT", color="blue")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks")
election_data = pd.read_csv("election.csv")  
sns.displot(data=election_data,x="city",y="VMOTHER", color="orange")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks")
election_data = pd.read_csv("election.csv")  
sns.displot(data=election_data,x="city",y="VCDPP", color="green")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks")
election_data = pd.read_csv("election.csv")  
sns.displot(data=election_data,x="city",y="VCKMT", color="blue")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks")
election_data = pd.read_csv("election.csv")  
sns.displot(data=election_data,x="city",y="VCOTHER", color="orange")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.barplot(data=election_data, x="city", y="VMKMT")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.barplot(data=election_data, x="city", y="VMOTHER")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.barplot(data=election_data, x="city", y="VCDPP")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.barplot(data=election_data, x="city", y="VCKMT")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.barplot(data=election_data, x="city", y="VCOTHER")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.scatterplot(data=election_data, x="VP", y="VMDPP",color='green')
# Out:
# <Axes: xlabel='VP', ylabel='VMDPP'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.scatterplot(data=election_data, x="VP", y="VMKMT",color='blue')
# Out:
# <Axes: xlabel='VP', ylabel='VMKMT'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.scatterplot(data=election_data, x="VP", y="VMOTHER",color="orange")
# Out:
# <Axes: xlabel='VP', ylabel='VMOTHER'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.scatterplot(data=election_data, x="VP", y="VCDPP",color='green')
# Out:
# <Axes: xlabel='VP', ylabel='VCDPP'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.scatterplot(data=election_data, x="VP", y="VCKMT",color='blue')
# Out:
# <Axes: xlabel='VP', ylabel='VCKMT'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
election_data = pd.read_csv("election.csv")  
sns.scatterplot(data=election_data, x="VP", y="VCOTHER",color="orange")
# Out:
# <Axes: xlabel='VP', ylabel='VCOTHER'>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("election.csv")
x = df.iloc[:, 3:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.854310887350535

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("election.csv")
x = df.iloc[:, 3:5]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.8505349276274387

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("election.csv")
x = df.iloc[:, 6:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.8492762743864065

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("Aelection.csv")
x = df.iloc[:, 3:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.8466453674121406

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("Belection.csv")
x = df.iloc[:, 3:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.956386292834891

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("Delection.csv")
x = df.iloc[:, 3:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.9886792452830189

# %%
df = pd.read_csv("Eelection.csv")
x = df.iloc[:, 3:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.947945205479452

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("Felection.csv")
x = df.iloc[:, 3:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.8387755102040816

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

df = pd.read_csv("Helection.csv")
x = df.iloc[:, 3:8]
y = df.iloc[:, 9]
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2)
transfer = StandardScaler()
x_train = transfer.fit_transform(x_train)
x_test = transfer.transform(x_test)
estimator = LogisticRegression()
estimator.fit(x_train, y_train)
score = estimator.score(x_test, y_test)
print("準確率：{}".format(score))
# Out:
# 準確率：0.8864628820960698
